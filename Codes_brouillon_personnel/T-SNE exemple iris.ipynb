# %%
from sklearn.manifold import TSNE
from keras.datasets import mnist
from sklearn.datasets import load_iris
from numpy import reshape
import seaborn as sns
import pandas as pd

# %%
 pip3 show tensorflow

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=123)
z = tsne.fit_transform(x)
# Out:
# C:\Users\Enzo\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Enzo\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 150 samples in 0.000s...
# [t-SNE] Computed neighbors for 150 samples in 0.019s...
# [t-SNE] Computed conditional probabilities for sample 150 / 150
# [t-SNE] Mean sigma: 0.509910
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.387634
# [t-SNE] KL divergence after 1000 iterations: 0.129141

# %%
df = pd.DataFrame()
df["y"] = y
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 3),
                data=df).set(title="Iris data T-SNE projection")
# Out:
# [Text(0.5, 1.0, 'Iris data T-SNE projection')]
