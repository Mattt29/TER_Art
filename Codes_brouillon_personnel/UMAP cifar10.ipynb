# %% [markdown]
# How to load and visualize CIFAR-10 dataset
# CIFAR Website: https://www.cs.toronto.edu/~kriz/cifa...

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
file=r"C:\Users\Enzo\Documents\Cours\TER_Art\Donnees\Cifar10\cifar-10-python\cifar-10-batches-py\data_batch_1"
data=unpickle(file)

# %%
data
# Out:
# {b'batch_label': b'training batch 1 of 5',
#  b'labels': [6,
#   9,
#   9,
#   4,
#   1,
#   1,
#   2,
#   7,
#   8,
#   3,
#   4,
#   7,
#   7,
#   2,
#   9,
#   9,
#   9,
#   3,
#   2,
#   6,
#   4,
#   3,
#   6,
#   6,
#   2,
#   6,
#   3,
#   5,
#   4,
#   0,
#   0,
#   9,
#   1,
#   3,
#   4,
#   0,
#   3,
#   7,
#   3,
#   3,
#   5,
#   2,
#   2,
#   7,
#   1,
#   1,
#   1,
#   2,
#   2,
#   0,
#   9,
#   5,
#   7,
#   9,
#   2,
#   2,
#   5,
#   2,
#   4,
#   3,
#   1,
#   1,
#   8,
#   2,
#   1,
#   1,
#   4,
#   9,
#   7,
#   8,
#   5,
#   9,
#   6,
#   7,
#   3,
#   1,
#   9,
#   0,
#   3,
#   1,
#   3,
#   5,
#   4,
#   5,
#   7,
#   7,
#   4,
#   7,
#   9,
#   4,
#   2,
#   3,
#   8,
#   0,
#   1,
#   6,
#   1,
#   1,
#   4,
#   1,
#   8,
#   3,
#   9,
#   6,
#   6,
#   1,
#   8,
#   5,
#   2,
#   9,
#   9,
#   8,
#   1,
#   7,
#   7,
#   0,
#   0,
#   6,
#   9,
#   1,
#   2,
#   2,
#   9,
#   2,
#   6,
#   6,
#   1,
#   9,
#   5,
#   0,
#   4,
#   7,
#   6,
#   7,
# ...

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 4

# %%
data.keys()
# Out:
# dict_keys([b'batch_label', b'labels', b'data', b'filenames'])

# %%
data=data[b'data']

# %%
data.shape

# %%
data[b'data'][0]

# %%
data[b'data'][0].shape

# %% [markdown]
# Reshape the image
# Reshape and transpose Image: https://miro.medium.com/max/814/1*8ml...
# Article on medium: https://towardsdatascience.com/cifar-...

# %%
image=data[b'data'][0]
image=image.reshape(3,32,32)
image

# %%
image=image.transpose(1,2,0)
print(image.shape)
image

# %%
image[1][23]

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
data=data[b'data']
data=data.reshape(len(data),3,32,32).transpose(0,2,3,1)
print(data.shape)
plt.imshow(data[0])

# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
import umap

# %%
reducer = umap.UMAP()
reducer.fit(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19732\1362080490.py in <module>
#       1 reducer = umap.UMAP()
# ----> 2 reducer.fit(data)
#
# ~\anaconda3\lib\site-packages\umap\umap_.py in fit(self, X, y)
#    2267         """
#    2268
# -> 2269         X = check_array(X, dtype=np.float32, accept_sparse="csr", order="C")
#    2270         self._raw_data = X
#    2271
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
# ...

# %%
embedding = reducer.transform(data)
# Verify that the result of calling transform is
# idenitical to accessing the embedding_ attribute
assert(np.all(embedding == reducer.embedding_))
embedding.shape
